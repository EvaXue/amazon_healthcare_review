# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_reviews_us_Health_Personal_Care_v1_00.tsv", delimiter="\t", error_bad_lines=False, encoding='utf-8')
df.head()
# Out:
# Skipping line 10317: expected 15 fields, saw 22
# Skipping line 40632: expected 15 fields, saw 22
# Skipping line 49643: expected 15 fields, saw 22
# Skipping line 54096: expected 15 fields, saw 22
# Skipping line 63958: expected 15 fields, saw 22
# Skipping line 64322: expected 15 fields, saw 22
#
# Skipping line 112718: expected 15 fields, saw 22
#
# Skipping line 156739: expected 15 fields, saw 22
# Skipping line 158865: expected 15 fields, saw 22
# Skipping line 192178: expected 15 fields, saw 22
#
# Skipping line 228364: expected 15 fields, saw 22
# Skipping line 228763: expected 15 fields, saw 22
# Skipping line 233558: expected 15 fields, saw 22
# Skipping line 234939: expected 15 fields, saw 22
# Skipping line 247329: expected 15 fields, saw 22
# Skipping line 250514: expected 15 fields, saw 22
# Skipping line 259994: expected 15 fields, saw 22
#
# Skipping line 278327: expected 15 fields, saw 22
# Skipping line 287267: expected 15 fields, saw 22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5312733 entries, 0 to 5312732
# Data columns (total 15 columns):
# marketplace          object
# customer_id          int64
# review_id            object
# product_id           object
# product_parent       int64
# product_title        object
# product_category     object
# star_rating          object
# helpful_votes        float64
# total_votes          float64
# vine                 object
# verified_purchase    object
# review_headline      object
# review_body          object
# review_date          object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 608.0+ MB

# %%
df.describe(include='all')
# Out:
#        marketplace   customer_id      review_id  product_id  product_parent  \
# count      5312733  5.312733e+06        5312733     5312733    5.312733e+06
# unique           1           NaN        5312733      488969             NaN
# top             US           NaN  RLWP6CTTVYW75  B001KXZ808             NaN
# freq       5312733           NaN              1       18935             NaN
# mean           NaN  2.737929e+07            NaN         NaN    5.049564e+08
# std            NaN  1.543210e+07            NaN         NaN    2.899034e+08
# min            NaN  1.000700e+04            NaN         NaN    1.212000e+03
# 25%            NaN  1.417488e+07            NaN         NaN    2.581094e+08
# 50%            NaN  2.581847e+07            NaN         NaN    5.049278e+08
# 75%            NaN  4.190605e+07            NaN         NaN    7.591054e+08
# max            NaN  5.309658e+07            NaN         NaN    9.999998e+08
#
# ...

# %%
df.review_date.sort_values(ascending=False).head()
# Out:
# 0       2015-08-31
# 6020    2015-08-31
# 6014    2015-08-31
# 6015    2015-08-31
# 6016    2015-08-31
# Name: review_date, dtype: object
