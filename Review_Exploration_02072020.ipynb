# %%
from datetime import date, datetime, timedelta
import pymysql
import csv
import os
from pandas import DataFrame
import pandas as pd
from sqlalchemy import create_engine
import mysql.connector
from mysql.connector import errorcode
import glob
import logging
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None
# for advanced visualizations
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected = True)
#import plotly.figure_factory as ff
# for basic visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import numpy as np
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
import nltk
#nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import line_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import BigramAssocMeasures, BigramCollocationFinder, TrigramAssocMeasures, TrigramCollocationFinder
import matplotlib.pyplot as plt
from nltk import sent_tokenize
from nltk import pos_tag, sent_tokenize, wordpunct_tokenize
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ##https://www.kaggle.com/roshansharma/amazon-alexa-reviews

# %%
df = pd.read_json('/Users/exue001c/evagit/amazon_healthcare_review/data/review_sample.json',orient='columns')

# %% [markdown]
# ### Rating Distribution

# %%
ratings = df['rating'].value_counts().sort_index(ascending=False)

label_rating = ratings.index
size_rating = ratings.values

colors = ['pink', 'lightblue', 'aqua', 'gold', 'crimson']

rating_piechart = go.Pie(labels = label_rating,
                         values = size_rating,
                         marker = dict(colors = colors),
                         name = 'Alexa', hole = 0.3)

rating_df = [rating_piechart]

layout = go.Layout(
           title = 'Distribution of Ratings for Crutch Pad')

fig = go.Figure(data = rating_df,
                 layout = layout)

py.iplot(fig)
display(ratings)
# Out:
# <div>
#
#
#             <div id="574fe270-7e98-4a8d-88e3-cd262d85496c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("574fe270-7e98-4a8d-88e3-cd262d85496c")) {
#                     Plotly.newPlot(
#                         '574fe270-7e98-4a8d-88e3-cd262d85496c',
#                         [{"hole": 0.3, "labels": [5, 4, 3, 2, 1], "marker": {"colors": ["pink", "lightblue", "aqua", "gold", "crimson"]}, "name": "Alexa", "type": "pie", "values": [1860, 290, 138, 82, 114]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...
# 5    1860
# 4     290
# 3     138
# 2      82
# 1     114
# Name: rating, dtype: int64

# %% [markdown]
# By looking at the above pie chart, we can infer that most of the Ratings are good for 14 Cruch pad products. Around 74.9% people have given this product 5 Star rating on amazon, which is very good. 11.7% people have given these products a 4 Star Rating, which is also good. that means 74.9+11.7 ~ 87% people have given Cruch pad good rating.
#
# A total of 3.3+4.59 ~8% people did not like Cruch pad they purchased.

# %%
color = plt.cm.copper(np.linspace(0, 1, 15))
df['product_id'].value_counts().plot.bar(color = color, figsize = (15, 9))

plt.title('Distribution of reviews of Cruch pad product on Amazon', fontsize = 20)
plt.xlabel('product_id')
plt.ylabel('count')
plt.show()

# %% [markdown]
# The above Bar plot, plots the different cruch pad product with their popularity or no. of counts.

# %%
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('fivethirtyeight')

sns.boxenplot(df['product_id'], df['rating'], palette = 'spring')
plt.title("Product ID vs Ratings")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The above Box plot, plots the distribution of the rating for each product.

# %% [markdown]
# The above Distribution Plot, shows a distribution of Length of the Reviews/title written by the customers. Most of the Reviews are are pretty short.

# %%
insignificant_taglist1= ['DT', 'CC','PRP','PRP$','IN','.','TO',"''",',','WRB','RP','WP','WDT',
         'EX','UH','$',':','FW','WP$','LS','SYM','VBD','VB','VBP','VBZ','VBG','VBN']
insignificant_taglist2 = ['DT', 'CC','PRP','PRP$','IN','.','TO',"''",',','WRB','RP','WP','WDT',
                                              'EX','UH','$',':','FW','WP$','LS','SYM']
significant_taglist_N =['NN','JJ','JJR','JJS','NNS','NNP','NNPS','PDT','POS']
significant_taglist_V =['RB','RBR','RBS','VB','VBD','VBN','VBP','VBZ','VBG']

# %%
def filter_insignificant(chunk, tag_suffixes =insignificant_taglist1):     
    good = [] 
    for word, tag in chunk: 
        if tag in tag_suffixes: 
            continue
        good.append((word, tag))   
    return good


def keep_significant(chunk, tag_suffixes =significant_taglist_N):
    good = [] 
    for word, tag in chunk: 
        if tag not in tag_suffixes: 
            continue
        good.append((word, tag))   
    return good

# %%
df.head()
# Out:
#       helpful_votes  product_id  rating  \
# 0                 0  B07H7Q1DFP       4
# 1                 0  B07HM7P88N       5
# 10                0  B07H7Q1DFP       5
# 100               0  B07HM7P88N       5
# 1000              0  B07GZYVJ6N       5
#
#                                                  review    review_date  \
# 0     Got these in hopes that my hands would not hur...  1553126400000
# 1     The product came very fast and it is very cush...  1557964800000
# 10    These babies have saved my armpits and the hee...  1571702400000
# 100                                   Worked out great.  1568592000000
# 1000  I purchased these for my daughter when she had...  1576627200000
#
#       review_len                                      title  title_len
# 0            418  Very soft, saves the hands and under arms         41
# 1             94                              It does work!         13
# 10           234         Comfort for longer term crutch use         34
# 100           17                                  All Good.          9
# 1000         139                          Very Nice Product         17

# %%
def getNGrams(wordlist, n):
    return ['_'.join(wordlist[i:i+n]) for i in range(len(wordlist)-(n-1))]

# %%
def word_frequency_chart(words):
    cv = CountVectorizer()
    words = cv.fit_transform(v_lemma_clean_list)
    sum_words = words.sum(axis=0)
    #display(sum_words)


    words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
    frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])
    #display(frequency)
    plt.style.use('fivethirtyeight')
    color = plt.cm.ocean(np.linspace(0, 1, 20))
    frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 6), color = color)
    plt.title("Most Frequently Occuring Words in %s - Top 30"%(flag))
    plt.show()

# %% [markdown]
# ### remove key searching words - 'crutch','pad'  from word coud

# %%
def Normalize_Tokens(review_series, flag,n):
    review_list=review_series.tolist()
    v_tokenized = [nltk.word_tokenize(message) for message in review_list]
    v_tokenized_tag = [pos_tag(nltk.wordpunct_tokenize(message.encode("utf-8"))) for message in review_list]
    stop_words = [ x.encode("utf-8") for x in stopwords.words('english') ]
    stop_words_skip =["don't","not","aren't","couldn't","didn't","doesn't","hadn't","hasn't","haven't","isn't","mightn't",
                     "mustn't","needn't","shan't","shouldn't","wasn't","weren't","wouldn't","won't",
                      'ain',"no",'nor','aren','couldn','didn','doesn','hadn','hasn','haven','isn','ma','mightn',
                      'mustn','needn','shan','shouldn','wasn','weren','won','wouldn']
    self_define_stop_wrods=['nan','crutch','pad','wa']
    stop_words=stop_words+self_define_stop_wrods
    stop_words2=[x for x in stop_words if x not in stop_words_skip]
    #display(stop_words2)
    ps = PorterStemmer()
    lemmatizer=WordNetLemmatizer()
    # Create a list for clean messages.
    tokens_len=len(v_tokenized)
    v_prelim = [None] * tokens_len
    v_lemma = [None] * tokens_len
    #v_lemma_counts_per_survey = [None] * tokens_len
    #n_v_lemma_counts_per_survey= [None] * tokens_len
    ngrams_v_lemma = [None] * tokens_len
    # Prep data and Bag-of-Words Analysis
    for i in range(len(v_tokenized)):
        # filter insignificant tag
        #v_prelim[i] = [word for word, tag in filter_insignificant(token_tag[i],filter_tag)]
        # filter insignificant tag
        # 1. Convert to lower case.
        v_prelim[i] = [message.lower() for message in v_tokenized[i]]
        # 2. Remove punctuation and any non-alphabetical characters.
        v_prelim[i] = [word for word in v_prelim[i] if word.isalpha()]
        # 3. Stem words.
        # Lemmitize words and record the word count
        #v_lemma[i] = [ps.stem(word) for word in v_prelim[i]]
        v_lemma[i] = [lemmatizer.lemmatize(word) for word in v_prelim[i]]
        # 4. Remove punctuation and any non-alphabetical characters.
        v_lemma[i] = [word for word in v_lemma[i] if  word not in stop_words2]
        #v_lemma_counts_per_survey[i] = len(v_lemma[i])
                ##ngram 
        ngrams_v_lemma[i] = getNGrams(v_lemma[i], n)
        #n_v_lemma_counts_per_survey[i] = len(ngrams_v_lemma[i])
       
    # Array with length of each survey
    #word_counts_array_lemma = np.array(v_lemma_counts_per_survey)
    #v_lemma_array = np.array(v_lemma)
    #doc_array = np.array(review_series)
    #print('Original Survey Size %s'%(len(v_lemma_array)))

    # Find indices of all messages where there are at least 1 words.
    #valid_v_lemma = np.where(word_counts_array_lemma >= 1)[0]
    #invalid_v_lemma = np.where(word_counts_array_lemma < 1)[0]
    #valid_v_lemma=word_counts_array_lemma
    #print('Survey Size W Valid Verbatim %s'%len(valid_v_lemma))
    #print('--------------Read invalid Verbatim ')
    #for i in range(30):
        #print (v_lemma_array[invalid_v_lemma][i],'\n')
        #print (doc_array[invalid_v_lemma][i],'\n')
    # Convert the array back to a list.

    # Join words in each message into a single character string.
    ngrams_v_lemma_clean_list = [' '.join(d) for d in ngrams_v_lemma]
    v_lemma_clean_list = [' '.join(d) for d in v_lemma]
    orig_doc_clean_list=[''.join(d) for d in review_list]
    #print(v_lemma_clean_list[:10])
    #print(orig_doc_clean_list[:10])
    lema_orig_list = [[i , j, k] for i, j,k in zip(v_lemma_clean_list,ngrams_v_lemma_clean_list,orig_doc_clean_list)] 
    lema_orig_df = pd.DataFrame.from_records(lema_orig_list, columns=['one_gram_lema_text','n_gram_lema_text','orig_text'])
    #print('--------------Verbatim after Lemmatization')
    #for i in range(5):
       # print(i, v_lemma_clean[i],'\n')
       # print(i, v_lemma_clean_list[i],'\n')
       # print (document[i],'\n')
   
    word_frequency_chart(v_lemma_clean_list)
    word_frequency_chart(ngrams_v_lemma_clean_list)
    
    cv = CountVectorizer()
    words = cv.fit_transform(v_lemma_clean_list)
    sum_words = words.sum(axis=0)
    #display(sum_words)


    words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
    words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
    frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])
    #display(frequency)
    plt.style.use('fivethirtyeight')
    color = plt.cm.ocean(np.linspace(0, 1, 20))
    frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 6), color = color)
    plt.title("Most Frequently Occuring Words in %s - Top 30"%(flag))
    plt.show()
    
    
    
    return lema_orig_df

# %%
review_transfered = Normalize_Tokens(df['review'] , 'Review',2)
title_transfered = Normalize_Tokens(df['title'] , 'Review',2)
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'nan',
#  'crutch',
#  'pad',
#  'wa']
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'nan',
#  'crutch',
#  'pad',
#  'wa']

# %%
display(review_transfered)
display(title_transfered)
# Out:
#                                      one_gram_lema_text  \
# 0     got hope hand would not hurt using comfortable...
# 1              product came fast cushy palm hand armpit
# 2     baby saved armpit heel hand recovering knee su...
# 3                                          worked great
# 4     purchased daughter surgery leg helpful adding ...
# 5     made carrying phone wallet even bottle water s...
# 6                didnt fit right bulky not tight closed
# 7               nice not add comfort much thought would
# 8
# 9     year old daughter broke foot place biggest pro...
# 10                                          comfortable
# 11      product helped much comfortable would recommend
# 12    exactly need use hold phone misc item great pr...
# 13                                     big help someone
# 14                                                great
# 15    set gift love worth star ordered another say d...
# 16    fast delivery good quality product able switch...
# 17    comfortable secure no reason think wo last lon...
# 18                                    made using better
# 19    fantastic product simple solution ha made life...
# 20    bag recommended friend no complaint made life ...
# 21                                          comfortable
# 22    poor daughter ankle issue make old look better...
# 23                  husband loved set said easy rebuild
# 24                                          comfortable
# 25    pair quite old maybe year rubber grip rest wee...
# 26                       made son time much comfortable
# 27                     hand grip portion large daughter
# 28    ive received many compliment bag cute also pra...
# 29    great product helped son much comfort convenience
# ...                                                 ...
# 2454              love soft material light weight cushy
# 2455  cute comfy easy use definitely worth make big ...
# 2456  daughter fractured ankle not comfortable old c...
# 2457  horrible second took packaging falling apart f...
# 2458  ha enough cushion take away pain color look pi...
# 2459             comfortable appreciated comfort needed
# 2460                    item working well used grandson
# 2461  daughter loved really helped reduce pain feeli...
# 2462  extended amount time highly recommend easy ins...
# 2463  product excellent addition daughter ha broken ...
# 2464                  suck make suck little bit le haha
# 2465                                        fit perfect
# 2466  soft comfortable highly recommend also check v...
# 2467  make son adjustment school easier allows put p...
# 2468  thing ha huge help loved could use carrying wa...
# 2469  great product purse kept slipping shoulder flo...
# 2470          work well not use hand grip cover tho bag
# 2471                        described yet small purpose
# 2472                      need exactly described seller
# 2473  purchased son broke leg husband wanted make su...
# 2474  day week sentence bearing post foot tendon rep...
# 2475                stuck month move frickin life saver
# 2476  got critter daughter broke leg help encourage ...
# 2477                       nice soft look good fit well
# 2478  fantastic product make using much tolerable pa...
# 2479  fit perfect little spit inside hand foot make ...
# 2480  not soft hard not problem might someone not us...
# 2481                            made injured way easier
# 2482  like comfort softness extra padding used knee ...
# 2483         arm little bulky hand great help callouses
#
#                                        n_gram_lema_text  \
# 0     got_hope hope_hand hand_would would_not not_hu...
# 1     product_came came_fast fast_cushy cushy_palm p...
# 2     baby_saved saved_armpit armpit_heel heel_hand ...
# 3                                          worked_great
# 4     purchased_daughter daughter_surgery surgery_le...
# 5     made_carrying carrying_phone phone_wallet wall...
# 6     didnt_fit fit_right right_bulky bulky_not not_...
# 7     nice_not not_add add_comfort comfort_much much...
# 8
# 9     year_old old_daughter daughter_broke broke_foo...
# 10
# 11    product_helped helped_much much_comfortable co...
# 12    exactly_need need_use use_hold hold_phone phon...
# 13                                big_help help_someone
# 14
# 15    set_gift gift_love love_worth worth_star star_...
# 16    fast_delivery delivery_good good_quality quali...
# 17    comfortable_secure secure_no no_reason reason_...
# 18                              made_using using_better
# 19    fantastic_product product_simple simple_soluti...
# 20    bag_recommended recommended_friend friend_no n...
# 21
# 22    poor_daughter daughter_ankle ankle_issue issue...
# 23    husband_loved loved_set set_said said_easy eas...
# 24
# 25    pair_quite quite_old old_maybe maybe_year year...
# 26         made_son son_time time_much much_comfortable
# 27    hand_grip grip_portion portion_large large_dau...
# 28    ive_received received_many many_compliment com...
# 29    great_product product_helped helped_son son_mu...
# ...                                                 ...
# 2454  love_soft soft_material material_light light_w...
# 2455  cute_comfy comfy_easy easy_use use_definitely ...
# 2456  daughter_fractured fractured_ankle ankle_not n...
# 2457  horrible_second second_took took_packaging pac...
# 2458  ha_enough enough_cushion cushion_take take_awa...
# 2459  comfortable_appreciated appreciated_comfort co...
# 2460  item_working working_well well_used used_grandson
# 2461  daughter_loved loved_really really_helped help...
# 2462  extended_amount amount_time time_highly highly...
# 2463  product_excellent excellent_addition addition_...
# 2464  suck_make make_suck suck_little little_bit bit...
# 2465                                        fit_perfect
# 2466  soft_comfortable comfortable_highly highly_rec...
# 2467  make_son son_adjustment adjustment_school scho...
# 2468  thing_ha ha_huge huge_help help_loved loved_co...
# 2469  great_product product_purse purse_kept kept_sl...
# 2470  work_well well_not not_use use_hand hand_grip ...
# 2471              described_yet yet_small small_purpose
# 2472    need_exactly exactly_described described_seller
# 2473  purchased_son son_broke broke_leg leg_husband ...
# 2474  day_week week_sentence sentence_bearing bearin...
# 2475  stuck_month month_move move_frickin frickin_li...
# 2476  got_critter critter_daughter daughter_broke br...
# 2477    nice_soft soft_look look_good good_fit fit_well
# 2478  fantastic_product product_make make_using usin...
# 2479  fit_perfect perfect_little little_spit spit_in...
# 2480  not_soft soft_hard hard_not not_problem proble...
# 2481                made_injured injured_way way_easier
# 2482  like_comfort comfort_softness softness_extra e...
# 2483  arm_little little_bulky bulky_hand hand_great ...
#
#                                               orig_text
# 0     Got these in hopes that my hands would not hur...
# 1     The product came very fast and it is very cush...
# 2     These babies have saved my armpits and the hee...
# 3                                     Worked out great.
# 4     I purchased these for my daughter when she had...
# 5     This made carrying my phone, wallet, or even a...
# 6      They didnt fit right; bulky and not tight closed
# 7     Nice, the do not add comfort as much as I thou...
# 8                                              Crutches
# 9     My 9 year old daughter broke her foot in 3 pla...
# 10                                    Very comfortable.
# 11    Product helped very much .  Very Comfortable ....
# 12    It is EXACTLY what you need when you have to u...
# 13                    big help to someone with crutches
# 14                                                Great
# 15    We have a set as a gift and love these. Worth ...
# 16    Very fast delivery, good quality product. Was ...
# 17    Very comfortable and secure.  No reason to thi...
# 18                        It made using crutches better
# 19    Fantastic product ! Its a simple solution that...
# 20    This crutch bag was recommended to me by a fri...
# 21                                     So comfortable!!
# 22    My poor daughter is on crutches again (ankle i...
# 23    Husband loved the set. He said is was easy to ...
# 24                                     Very comfortable
# 25    Pair of crutches I had were quite old. Maybe 3...
# 26    "Made my sons time on crutches much more comfo...
# 27    The hand grip portion was too large for my 10 ...
# 28    Ive received so many compliments on this bag. ...
# 29    Great product, helped my son out so much with ...
# ...                                                 ...
# 2454  I love how soft the material is and so light w...
# 2455  The pads are cute, comfy and easy to use! Defi...
# 2456  My Daughter fractured her ankle and crutches a...
# 2457  These were horrible from the second I took the...
# 2458  Has just enough cushion to take away from the ...
# 2459  Very comfortable I appreciated the comfort whe...
# 2460  This item is working well. Used them on crutch...
# 2461  My daughter loved these for her crutches. They...
# 2462  If you have to be on crutches for an extended ...
# 2463  Product was an excellent addition to the crutc...
# 2464  Crutches suck... These make them suck a little...
# 2465                                    Fit was perfect
# 2466  Very soft and comfortable, highly recommend. A...
# 2467  this makes my sons adjustment to school easier...
# 2468  This thing has been a huge help! I loved that ...
# 2469  A great product! My purse kept slipping off my...
# 2470  It works well. I did not use the hand grip cov...
# 2471            As described, yet small for my purpose.
# 2472  If you're on Crutches, you need this!!!Exactly...
# 2473  Purchased this for my son who is 13 and broke ...
# 2474  I'm 5 days into a 3 week sentence of non-weigh...
# 2475  If you're stuck on crutches for a few months t...
# 2476  We got the crutch critters when my daughter br...
# 2477  These are very nice. Very soft and look good. ...
# 2478  This is a fantastic product! These pads make u...
# 2479  Fit perfect on "Quik-Fit" crutches.  A little ...
# 2480  They are not soft at all. Hard. It's not a pro...
# 2481               These made being injured way easier.
# 2482  Like the comfort and softness of extra padding...
# 2483  The arm pads are a little bulky, the hand pads...
#
# [2484 rows x 3 columns]
#                                      one_gram_lema_text  \
# 0                                    soft save hand arm
# 1                                              doe work
# 2                               comfort longer term use
# 3                                                  good
# 4                                          nice product
# 5                                               awesome
# 6                                         not made well
# 7                                              two star
# 8                                               comfort
# 9                                         great product
# 10                                             good buy
# 11                                          comfortable
# 12                                        great product
# 13                                                 like
# 14                           buy item right start using
# 15                                         not received
# 16                                 good quality product
# 17                                          comfortable
# 18                                              comfort
# 19            fantastic product simple solution ha made
# 20                               bag recommended friend
# 21                                          comfortable
# 22                                           cute comfy
# 23                                            five star
# 24                                              perfect
# 25                                    great replacement
# 26                                 comfortable addition
# 27                               great underarm comfort
# 28                 also love ha carabeener clip perfect
# 29                                            five star
# ...                                                 ...
# 2454                                              cushy
# 2455                              make world difference
# 2456       daughter fractured ankle not comfortable old
# 2457                                            get pay
# 2458                                          doe trick
# 2459                                        comfortable
# 2460
# 2461                                     feeling armpit
# 2462            highly recommend easy install well made
# 2463                                  easy install soft
# 2464                       suck make suck little bit le
# 2465                                perfect replacement
# 2466                                          worth buy
# 2467           make son adjustment school easier allows
# 2468                make life broken leg lot convenient
# 2469         great product purse kept slipping shoulder
# 2470                                           good buy
# 2471                                         three star
# 2472                                    awesome someone
# 2473                                 highly recommended
# 2474                               provides huge relief
# 2475                                               must
# 2476                  conversation starter amazing idea
# 2477                                               nice
# 2478                         saving grace great comfort
# 2479                                           buy glad
# 2480
# 2481                                            helpful
# 2482  amazing product vive sheepskin help comfort using
# 2483                                             needed
#
#                                        n_gram_lema_text  \
# 0                          soft_save save_hand hand_arm
# 1                                              doe_work
# 2                   comfort_longer longer_term term_use
# 3
# 4                                          nice_product
# 5
# 6                                    not_made made_well
# 7                                              two_star
# 8
# 9                                         great_product
# 10                                             good_buy
# 11
# 12                                        great_product
# 13
# 14          buy_item item_right right_start start_using
# 15                                         not_received
# 16                         good_quality quality_product
# 17
# 18
# 19    fantastic_product product_simple simple_soluti...
# 20                   bag_recommended recommended_friend
# 21
# 22                                           cute_comfy
# 23                                            five_star
# 24
# 25                                    great_replacement
# 26                                 comfortable_addition
# 27                      great_underarm underarm_comfort
# 28    also_love love_ha ha_carabeener carabeener_cli...
# 29                                            five_star
# ...                                                 ...
# 2454
# 2455                        make_world world_difference
# 2456  daughter_fractured fractured_ankle ankle_not n...
# 2457                                            get_pay
# 2458                                          doe_trick
# 2459
# 2460
# 2461                                     feeling_armpit
# 2462  highly_recommend recommend_easy easy_install i...
# 2463                          easy_install install_soft
# 2464  suck_make make_suck suck_little little_bit bit_le
# 2465                                perfect_replacement
# 2466                                          worth_buy
# 2467  make_son son_adjustment adjustment_school scho...
# 2468  make_life life_broken broken_leg leg_lot lot_c...
# 2469  great_product product_purse purse_kept kept_sl...
# 2470                                           good_buy
# 2471                                         three_star
# 2472                                    awesome_someone
# 2473                                 highly_recommended
# 2474                          provides_huge huge_relief
# 2475
# 2476  conversation_starter starter_amazing amazing_idea
# 2477
# 2478             saving_grace grace_great great_comfort
# 2479                                           buy_glad
# 2480
# 2481
# 2482  amazing_product product_vive vive_sheepskin sh...
# 2483
#
#                                               orig_text
# 0             Very soft, saves the hands and under arms
# 1                                         It does work!
# 2                    Comfort for longer term crutch use
# 3                                             All Good.
# 4                                     Very Nice Product
# 5                                               Awesome
# 6                                         Not made well
# 7                                             Two Stars
# 8                                               Comfort
# 9                                         Great product
# 10                                             Good buy
# 11                                     Very Comfortable
# 12                                       Great product!
# 13                                                 like
# 14    Buy this item right when you have to start usi...
# 15                                         Not received
# 16                                 good quality product
# 17                                          Comfortable
# 18                                              Comfort
# 19    Fantastic product! Its a simple solution that ...
# 20    This crutch bag was recommended to me by a friend
# 21                                     So comfortable!!
# 22                                         Cute & comfy
# 23                                           Five Stars
# 24                                              Perfect
# 25                   Great replacement for our crutches
# 26                                 Comfortable addition
# 27                               Great underarm comfort
# 28    I also love how it has a carabeener clip which...
# 29                                           Five Stars
# ...                                                 ...
# 2454                                              Cushy
# 2455                       Makes a world of difference!
# 2456  My Daughter fractured her ankle and crutches a...
# 2457                           You get what you pay for
# 2458                                    Does the trick.
# 2459                                   Very comfortable
# 2460                                        Crutch pads
# 2461                          feeling under her armpits
# 2462  I highly recommend this! Easy to install and w...
# 2463                      Easy to install and very soft
# 2464  Crutches suck... These make them suck a little...
# 2465                                Perfect replacement
# 2466                                     Worth the buy!
# 2467  this makes my sons adjustment to school easier...
# 2468  Makes life with a broken leg,  a lot more conv...
# 2469  A great product! My purse kept slipping off my...
# 2470                                           Good buy
# 2471                                        Three Stars
# 2472                  Awesome for someone on crutches!!
# 2473                                 Highly Recommended
# 2474                               Provides huge relief
# 2475                                          Must have
# 2476              Conversation starter and amazing idea
# 2477                                         Very nice!
# 2478                      Saving Grace.  Great comfort!
# 2479                 Buy these, you'll be glad you did.
# 2480                                        Crutch pads
# 2481                                           Helpful!
# 2482  Amazing product. Vive sheepskin helps with the...
# 2483                                Just what I needed.
#
# [2484 rows x 3 columns]

# %%
chatbox_mask = np.array(Image.open("image/chatbox2.png"))
#chatbox_mask

# %%
def generate_wordcloud(words,n_gram_words, mask,flag):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white', mask=mask).generate(words)
    word_cloud2 = WordCloud(width = 512, height = 512, background_color='white', mask=mask).generate(n_gram_words)

    plt.style.use('fivethirtyeight')
    #plt.title('%s for Cruch pad product on Amazon'%(flag), fontsize = 20, loc='center')

    f =plt.figure(figsize=(30,10),facecolor = 'white', edgecolor='blue')
    plt.axis('off')
    f.add_subplot(1,2, 1)
    plt.imshow(word_cloud, interpolation='bilinear')
    plt.axis('off')

    f.add_subplot(1,2, 2)
    # Display the generated image:
    # the matplotlib way:
    plt.imshow(word_cloud2, interpolation='bilinear')
    
    plt.axis('off')

    plt.tight_layout(pad=0)
    plt.show()

# %%
generate_wordcloud(''.join(review_transfered.one_gram_lema_text.to_list()), ''.join(review_transfered.n_gram_lema_text.to_list()),chatbox_mask, 'Review')
generate_wordcloud(''.join(title_transfered.one_gram_lema_text.to_list()), ''.join(title_transfered.n_gram_lema_text.to_list()), chatbox_mask,'Review title')

# %%
lemma_corpus_freq_dist = Freq_DTM_lemma.to_dict()
## frequent to percentage 
lemma_corpus_pec_dist = dict((k,[v ,Total_Docs,float(v)/float(Total_Docs),sub1]) for k,v in lemma_corpus_freq_dist.items() if float(v)/float(Total_Docs)>0.000001)
lemma_corpus_pec_df = pd.DataFrame.from_dict(lemma_corpus_pec_dist, orient='index')

# %%
# Transform your mask into a new one that will work with the function:
transformed_chatbox_mask = np.ndarray((chatbox_mask.shape[0],chatbox_mask.shape[1],chatbox_mask.shape[2]), np.int32)

for i in range(len(chatbox_mask)):
    transformed_chatbox_mask[i] = list(map(transform_format, chatbox_mask[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-7530a4bb8ff3> in <module>()
#       3
#       4 for i in range(len(chatbox_mask)):
# ----> 5     transformed_chatbox_mask[i] = list(map(transform_format, chatbox_mask[i]))
#
# <ipython-input-46-d975958b5210> in transform_format(val)
#       1 def transform_format(val):
# ----> 2     if val == 0:
#       3         return 255
#       4     else:
#       5         return val
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Create a word cloud image
wc = WordCloud(background_color="white", max_words=1000, mask=transformed_wine_mask,
               stopwords=stopwords, contour_width=3, contour_color='firebrick')

# Generate a wordcloud
wc.generate(text)

# store to file
wc.to_file("img/wine.png")

# show
plt.figure(figsize=[20,10])
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# 160477

# %% [markdown]
# Most reviews have less than 25 meaningful words.

# %%
from sklearn.feature_extraction.text import CountVectorizer


cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(output.lema_text)

# %%
cv.get_feature_names()
# Out:
# [u'abad',
#  u'abandon',
#  u'abil',
#  u'abl',
#  u'abras',
#  u'absolut',
#  u'absorb',
#  u'abus',
#  u'accent',
#  u'accept',
#  u'access',
#  u'accessori',
#  u'accesssori',
#  u'accid',
#  u'accident',
#  u'accommod',
#  u'accord',
#  u'account',
#  u'accur',
#  u'ach',
#  u'achi',
#  u'achil',
#  u'acl',
#  u'act',
#  u'activ',
#  u'actual',
#  u'ad',
#  u'add',
#  u'addit',
#  u'adequ',
#  u'adjust',
#  u'administ',
#  u'admittedli',
#  u'adopt',
#  u'ador',
#  u'adult',
#  u'advanc',
#  u'adventur',
#  u'advert',
#  u'advertis',
#  u'advis',
#  u'aesthet',
#  u'affect',
#  u'affili',
#  u'afford',
#  u'afraid',
#  u'aftermarket',
#  u'afterna',
#  u'afterward',
#  u'aga',
#  u'age',
#  u'aggrav',
#  u'ago',
#  u'agon',
#  u'agoni',
#  u'ahead',
#  u'ahhh',
#  u'aid',
#  u'ail',
#  u'air',
#  u'airplan',
#  u'airpod',
#  u'airport',
#  u'ajax',
#  u'ak',
#  u'aka',
#  u'ala',
#  u'alittl',
#  u'allevi',
#  u'allow',
#  u'alon',
#  u'alot',
#  u'alphabet',
#  u'alreadi',
#  u'alter',
#  u'altern',
#  u'aluminum',
#  u'alway',
#  u'amanda',
#  u'amaz',
#  u'amazingli',
#  u'amazon',
#  u'ampl',
#  u'amput',
#  u'ampute',
#  u'angl',
#  u'anim',
#  u'ankl',
#  u'annoy',
#  u'anoth',
#  u'anotherwis',
#  u'answer',
#  u'antibacteri',
#  u'anticip',
#  u'anxieti',
#  u'anymor',
#  u'anyon',
#  u'anyth',
#  u'anytim',
#  u'anywher',
#  u'apart',
#  u'appar',
#  u'appeal',
#  u'appear',
#  u'appl',
#  u'appli',
#  u'applic',
#  u'appreci',
#  u'approxim',
#  u'appt',
#  u'aqua',
#  u'area',
#  u'arm',
#  u'armi',
#  u'armpit',
#  u'arriv',
#  u'arthriti',
#  u'arthroscopi',
#  u'articl',
#  u'asap',
#  u'ashtray',
#  u'asid',
#  u'ask',
#  u'aspect',
#  u'assembl',
#  u'assempli',
#  u'assist',
#  u'associ',
#  u'assort',
#  u'assum',
#  u'athlet',
#  u'attach',
#  u'attempt',
#  u'attende',
#  u'attent',
#  u'attest',
#  u'attic',
#  u'attract',
#  u'attribut',
#  u'august',
#  u'auto',
#  u'automat',
#  u'autonom',
#  u'avail',
#  u'averag',
#  u'avid',
#  u'avoid',
#  u'aw',
#  u'await',
#  u'awar',
#  u'away',
#  u'awesom',
#  u'awhil',
#  u'awkward',
#  u'awkwardli',
#  u'awsom',
#  u'awsomev',
#  u'axilla',
#  u'baaaaar',
#  u'babi',
#  u'backpack',
#  u'backward',
#  u'bad',
#  u'badli',
#  u'bag',
#  u'baith',
#  u'bake',
#  u'balanc',
#  u'ball',
#  u'balm',
#  u'banana',
#  u'band',
#  u'bandag',
#  u'bang',
#  u'bankcard',
#  u'bar',
#  u'bare',
#  u'bareabl',
#  u'bargain',
#  u'base',
#  u'basement',
#  u'basi',
#  u'basic',
#  u'basket',
#  u'batch',
#  u'bathroom',
#  u'battl',
#  u'bc',
#  u'beach',
#  u'bear',
#  u'bearabl',
#  u'beast',
#  u'beat',
#  u'beauti',
#  u'becam',
#  u'becom',
#  u'bed',
#  u'bee',
#  u'beef',
#  u'beer',
#  u'befro',
#  u'beg',
#  u'began',
#  u'begin',
#  u'begun',
#  u'beingbon',
#  u'believ',
#  u'belli',
#  u'bend',
#  u'benefici',
#  u'benefit',
#  u'bent',
#  u'besid',
#  u'best',
#  u'better',
#  u'betteri',
#  u'beverag',
#  u'bewar',
#  u'bf',
#  u'bias',
#  u'bicycl',
#  u'big',
#  u'bigger',
#  u'biggest',
#  u'bigggggg',
#  u'biggi',
#  u'bike',
#  u'bilater',
#  u'bin',
#  u'bit',
#  u'bite',
#  u'biz',
#  u'bk',
#  u'black',
#  u'bled',
#  u'bless',
#  u'blister',
#  u'block',
#  u'blow',
#  u'blue',
#  u'bodi',
#  u'bodyweight',
#  u'bone',
#  u'bonu',
#  u'book',
#  u'boost',
#  u'booster',
#  u'boot',
#  u'bore',
#  u'borrow',
#  u'boss',
#  u'bother',
#  u'botk',
#  u'bottl',
#  u'bough',
#  u'bought',
#  u'bound',
#  u'bout',
#  u'box',
#  u'boy',
#  u'boyfriend',
#  u'brace',
#  u'brand',
#  u'bread',
#  u'break',
#  u'breast',
#  u'bright',
#  u'brilliant',
#  u'bring',
#  u'brittl',
#  u'broke',
#  u'broken',
#  u'broker',
#  u'brother',
#  u'brought',
#  u'bruis',
#  u'brunt',
#  u'brush',
#  u'brutal',
#  u'buck',
#  u'bucket',
#  u'buckl',
#  u'buddi',
#  u'buena',
#  u'bug',
#  u'build',
#  u'built',
#  u'bulg',
#  u'bulk',
#  u'bulki',
#  u'bullet',
#  u'bum',
#  u'bump',
#  u'bunch',
#  u'bunchi',
#  u'bundl',
#  u'bunion',
#  u'burden',
#  u'buri',
#  u'burn',
#  u'busi',
#  u'buy',
#  u'buyer',
#  u'ca',
#  u'cabinet',
#  u'caddi',
#  u'cailut',
#  u'cake',
#  u'calf',
#  u'california',
#  u'callous',
#  u'callus',
#  u'came',
#  u'camo',
#  u'camouflag',
#  u'camp',
#  u'campu',
#  u'cancer',
#  u'cane',
#  u'canva',
#  u'cap',
#  u'car',
#  u'carabeen',
#  u'carabin',
#  u'card',
#  u'care',
#  u'cariben',
#  u'carri',
#  u'cart',
#  u'cartilag',
#  u'cartwheel',
#  u'case',
#  u'cash',
#  u'cast',
#  u'cat',
#  u'catch',
#  u'categori',
#  u'caught',
#  u'caus',
#  u'caution',
#  u'cautiou',
#  u'caveat',
#  u'cell',
#  u'cellphon',
#  u'cent',
#  u'center',
#  u'centimet',
#  u'certainli',
#  u'chaf',
#  u'chafe',
#  u'chain',
#  u'chair',
#  u'challeng',
#  u'champ',
#  u'chanc',
#  u'chang',
#  u'changer',
#  u'chapstick',
#  u'charact',
#  u'charger',
#  u'charli',
#  u'cheap',
#  u'cheaper',
#  u'cheapli',
#  u'check',
#  u'checkbook',
#  u'cheer',
#  u'cheetah',
#  u'chest',
#  u'chief',
#  u'child',
#  u'childish',
#  u'children',
#  u'choic',
#  u'cholorx',
#  u'choos',
#  u'chose',
#  u'christian',
#  u'christma',
#  u'chuck',
#  u'chunk',
#  u'church',
#  u'cigarett',
#  u'cinch',
#  u'circul',
#  u'circular',
#  u'citizen',
#  u'claim',
#  u'clap',
#  u'clasp',
#  u'class',
#  u'classi',
#  u'classic',
#  u'classier',
#  u'clean',
#  u'cleanabl',
#  u'cleaner',
#  u'cleanli',
#  u'cleanup',
#  u'clear',
#  u'clever',
#  u'click',
#  u'client',
#  u'climat',
#  u'clip',
#  u'close',
#  u'closur',
#  u'cloth',
#  u'cloud',
#  u'clue',
#  u'clump',
#  u'clumpi',
#  u'clumsi',
#  u'clutch',
#  u'coat',
#  u'code',
#  u'coffe',
#  u'coke',
#  u'cold',
#  u'collaps',
#  u'colleg',
#  u'color',
#  u'comb',
#  u'combin',
#  u'come',
#  u'comfi',
#  u'comfier',
#  u'comfort',
#  u'comfortablemi',
#  u'comftorbl',
#  u'comic',
#  u'comment',
#  u'commerci',
#  u'commiss',
#  u'common',
#  u'commun',
#  u'commut',
#  u'compani',
#  u'compar',
#  u'comparison',
#  u'compart',
#  u'compel',
#  u'compens',
#  u'compet',
#  u'complain',
#  u'complaint',
#  u'complement',
#  u'complet',
#  u'complex',
#  u'complic',
#  u'compliment',
#  u'compra',
#  u'compress',
#  u'compromis',
#  u'concept',
#  u'concern',
#  u'condit',
#  u'confid',
#  u'confin',
#  u'confirm',
#  u'confus',
#  u'connect',
#  u'consecut',
#  u'consid',
#  u'consider',
#  u'consist',
#  u'constant',
#  u'constantli',
#  u'construct',
#  u'contact',
#  u'contain',
#  u'content',
#  u'continu',
#  u'control',
#  u'conveni',
#  u'convent',
#  u'convers',
#  u'convinc',
#  u'cooki',
#  u'cool',
#  u'coordin',
#  u'cope',
#  u'cord',
#  u'corner',
#  u'correct',
#  u'correctli',
#  u'cosmet',
#  u'cost',
#  u'couch',
#  u'couldv',
#  u'count',
#  u'coupl',
#  u'cours',
#  u'coushion',
#  u'cover',
#  u'coverag',
#  u'coversth',
#  u'cowboy',
#  u'cowgirl',
#  u'crack',
#  u'crafti',
#  u'cramp',
#  u'crap',
#  u'crawl',
#  u'crazi',
#  u'cream',
#  u'creat',
#  u'creator',
#  u'credit',
#  u'cri',
#  u'critchinf',
#  u'critic',
#  u'critiqu',
#  u'critter',
#  u'cross',
#  u'crossbar',
#  u'crouch',
#  u'cruch',
#  u'cructher',
#  u'cruella',
#  u'cruis',
#  u'crumbl',
#  u'crunch',
#  u'crurch',
#  u'crush',
#  u'crutch',
#  u'crutcher',
#  u'crutchesi',
#  u'crutcheswould',
#  u'crutchez',
#  u'cruthc',
#  u'crutsh',
#  u'cuddli',
#  u'cumbersom',
#  u'cup',
#  u'current',
#  u'curs',
#  u'cush',
#  u'cushey',
#  u'cushi',
#  u'cushion',
#  u'cushioni',
#  u'cusion',
#  u'custom',
#  u'cut',
#  u'cute',
#  u'cuter',
#  u'cutest',
#  u'cuz',
#  u'cv',
#  u'cvc',
#  u'cycl',
#  u'cyst',
#  u'dad',
#  u'daili',
#  u'damag',
#  u'damn',
#  u'damp',
#  u'dang',
#  u'danger',
#  u'dark',
#  u'darker',
#  u'darn',
#  u'data',
#  u'date',
#  u'daughter',
#  u'day',
#  u'deal',
#  u'dealt',
#  u'death',
#  u'debacl',
#  u'debit',
#  u'decay',
#  u'deceiv',
#  u'decent',
#  u'decid',
#  u'decis',
#  u'decor',
#  u'decreas',
#  u'deep',
#  u'def',
#  u'default',
#  u'defeat',
#  u'defect',
#  u'defiantli',
#  u'defin',
#  u'definatley',
#  u'definit',
#  u'del',
#  u'delic',
#  u'deliv',
#  u'deliveri',
#  u'dens',
#  u'denser',
#  u'densiti',
#  u'depart',
#  u'depend',
#  u'depict',
#  u'depress',
#  u'depth',
#  u'describ',
#  u'descript',
#  u'deserv',
#  u'design',
#  u'desper',
#  u'despit',
#  u'destroy',
#  u'detach',
#  u'deterior',
#  u'devast',
#  u'develop',
#  u'devic',
#  u'devil',
#  u'diabet',
#  u'diaper',
#  u'didnt',
#  u'die',
#  u'diet',
#  u'differ',
#  u'difficult',
#  u'difficulti',
#  u'dig',
#  u'dime',
#  u'dimens',
#  u'direct',
#  u'dirt',
#  u'dirti',
#  u'disabl',
#  u'disappoint',
#  u'discharg',
#  u'discomfort',
#  u'discount',
#  u'discov',
#  u'dish',
#  u'dishearten',
#  u'disintegr',
#  u'dislik',
#  u'disloc',
#  u'disney',
#  u'disneydenizen',
#  u'disneyland',
#  u'dissapoint',
#  u'disservic',
#  u'dist',
#  u'distanc',
#  u'distant',
#  u'distract',
#  u'ditch',
#  u'doabl',
#  u'doc',
#  u'doctor',
#  u'doesnt',
#  u'dog',
#  u'doll',
#  u'dollar',
#  u'donat',
#  u'dont',
#  u'door',
#  u'dope',
#  u'dopey',
#  u'dorm',
#  u'doubl',
#  u'doubt',
#  u'downsid',
#  u'downtown',
#  u'dozen',
#  u'dr',
#  u'drab',
#  u'drain',
#  u'drainupd',
#  u'dramat',
#  u'drastic',
#  u'drawback',
#  u'dread',
#  u'dream',
#  u'dress',
#  u'dresser',
#  u'dri',
#  u'drink',
#  u'driver',
#  u'drnk',
#  u'drop',
#  u'drugstor',
#  u'dryer',
#  u'duck',
#  u'duct',
#  u'dull',
#  u'durabl',
#  u'durat',
#  u'dust',
#  u'duti',
#  u'dye',
#  u'ea',
#  u'earbud',
#  u'earli',
#  u'earlier',
#  u'eas',
#  u'easi',
#  u'easier',
#  u'easiest',
#  u'easili',
#  u'eat',
#  u'echo',
#  u'ecstat',
#  u'edg',
#  u'edit',
#  u'effect',
#  u'effici',
#  u'effort',
#  u'eith',
#  u'elabor',
#  u'elast',
#  u'elbow',
#  u'elderli',
#  u'elementari',
#  u'elimin',
#  u'els',
#  u'elsewher',
#  u'em',
#  u'email',
#  u'embarrass',
#  u'emphat',
#  u'empti',
#  u'enabl',
#  u'encourag',
#  u'end',
#  u'endur',
#  u'enjoy',
#  u'enorm',
#  u'ensur',
#  u'entir',
#  u'equal',
#  u'equip',
#  u'er',
#  u'ergonom',
#  u'errand',
#  u'error',
#  u'escap',
#  u'especi',
#  u'essenti',
#  u'eta',
#  u'event',
#  u'eventu',
#  u'everi',
#  u'everybodi',
#  u'everyday',
#  u'everyon',
#  u'everyth',
#  u'everytim',
#  u'everywher',
#  u'evryth',
#  u'ewww',
#  u'exact',
#  u'exactli',
#  u'exampl',
#  u'exce',
#  u'exceed',
#  u'excel',
#  u'excellent',
#  u'excess',
#  u'exchang',
#  u'excit',
#  u'excruci',
#  u'exist',
#  u'expect',
#  u'expediti',
#  u'expens',
#  u'experi',
#  u'experienc',
#  u'explain',
#  u'explan',
#  u'explanatori',
#  u'express',
#  u'extend',
#  u'extens',
#  u'extra',
#  u'extrem',
#  u'eye',
#  u'eze',
#  u'fabric',
#  u'fabul',
#  u'face',
#  u'facecloth',
#  u'facil',
#  u'fact',
#  u'factor',
#  u'factori',
#  u'fail',
#  u'fair',
#  u'fairli',
#  u'fake',
#  u'fall',
#  u'fallen',
#  u'fals',
#  u'famili',
#  u'fan',
#  u'fanni',
#  u'fantast',
#  u'far',
#  u'farthest',
#  u'fashion',
#  u'fast',
#  u'fasten',
#  u'fat',
#  u'fatigu',
#  u'fault',
#  u'favor',
#  u'favorit',
#  u'febrez',
#  u'februari',
#  u'feed',
#  u'feedback',
#  u'feel',
#  u'feet',
#  u'fell',
#  u'fellow',
#  u'felt',
#  u'femal',
#  u'feminin',
#  u'femorosteoplasti',
#  u'fenc',
#  u'fianc\xe9',
#  u'fiber',
#  u'fibula',
#  u'field',
#  u'fight',
#  u'figur',
#  u'final',
#  u'fine',
#  u'finger',
#  u'finish',
#  u'firm',
#  u'firmli',
#  u'fish',
#  u'fit',
#  u'fitment',
#  u'fix',
#  u'fl',
#  u'flabbi',
#  u'flap',
#  u'flare',
#  u'flat',
#  u'flatten',
#  u'flaw',
#  u'flawlessli',
#  u'fleec',
#  u'flexibl',
#  u'flimsi',
#  u'flip',
#  u'floor',
#  u'flop',
#  u'floppi',
#  u'florida',
#  u'floss',
#  u'fluff',
#  u'fluffen',
#  u'fluffi',
#  u'fluffier',
#  u'fluid',
#  u'foam',
#  u'focu',
#  u'focus',
#  u'fold',
#  u'folk',
#  u'follow',
#  u'fond',
#  u'food',
#  u'fool',
#  u'foot',
#  u'forbid',
#  u'forc',
#  u'forearm',
#  u'forev',
#  u'forget',
#  u'forgot',
#  u'forgotten',
#  u'fork',
#  u'form',
#  u'formerli',
#  u'forth',
#  u'forti',
#  u'fortun',
#  u'forward',
#  u'fot',
#  u'fourth',
#  u'fractur',
#  u'frankli',
#  u'fray',
#  u'fred',
#  u'free',
#  u'freedom',
#  u'frequent',
#  u'fresh',
#  u'freshen',
#  u'frickin',
#  u'friction',
#  u'fridg',
#  u'friend',
#  u'friendli',
#  u'frtom',
#  u'frustrat',
#  u'fulli',
#  u'fun',
#  u'function',
#  u'fund',
#  u'funk',
#  u'funki',
#  u'funni',
#  u'fur',
#  u'fusion',
#  u'fuss',
#  u'futur',
#  u'fuzz',
#  u'fuzzi',
#  u'fyi',
#  u'gadget',
#  u'gag',
#  u'gain',
#  u'gal',
#  u'galaxi',
#  u'game',
#  u'garag',
#  u'garbag',
#  u'garden',
#  u'gather',
#  u'gave',
#  u'gel',
#  u'gem',
#  u'gener',
#  u'gentl',
#  u'gentler',
#  u'getter',
#  u'gf',
#  u'giant',
#  u'gift',
#  u'girl',
#  u'girlfriend',
#  u'given',
#  u'glad',
#  u'glass',
#  u'gloss',
#  u'glove',
#  u'glow',
#  u'glu',
#  u'glucos',
#  u'god',
#  u'godsend',
#  u'goe',
#  u'gold',
#  u'golf',
#  u'gon',
#  u'gone',
#  u'good',
#  u'goodi',
#  u'goodwil',
#  u'goofbal',
#  u'goofi',
#  u'gosh',
#  u'got',
#  u'gotten',
#  u'gout',
#  u'grab',
#  u'grace',
#  u'grade',
#  u'graduat',
#  u'grand',
#  u'grandaught',
#  u'grandchild',
#  u'granddaught',
#  u'grandson',
#  u'grant',
#  u'grasp',
#  u'grate',
#  u'gratefullli',
#  u'gray',
#  u'great',
#  u'greater',
#  u'greatest',
#  u'greatli',
#  u'green',
#  u'grest',
#  u'grey',
#  u'grip',
#  u'grippi',
#  u'groom',
#  u'gross',
#  u'ground',
#  u'grownup',
#  u'growth',
#  u'guarante',
#  u'guard',
#  u'guardian',
#  u'guess',
#  u'gum',
#  u'guy',
#  u'hack',
#  u'haha',
#  u'hahaha',
#  u'hair',
#  u'half',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer


cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(output.lema_text)
sum_words = words.sum(axis=0)


words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)
frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

plt.style.use('fivethirtyeight')
color = plt.cm.ocean(np.linspace(0, 1, 20))
frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 6), color = color)
plt.title("Most Frequently Occuring Words - Top 30")
plt.show()

# %% [markdown]
# The Above Bar plot gives us a rough idea about what customers mentioned most in their review.
#
# We can see that love is the most frequent word in the word suggesting that most of the people absolutely love alexa. Other frequent words that suggest alexa is doing well are amazing, like, great, works etc.
